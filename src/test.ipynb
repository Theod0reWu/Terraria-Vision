# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

from sprite_tools import get_sprite, downsample, is_blank, get_dimensions, display, get_sprite_custom
from base_dataset import TestDataset

# %%
# path = "../images/terraria_tiles/Tiles_264.png"
# path = "../images/terraria_tiles/Tiles_125.png"
path = "../images/terraria_tiles/Tiles_216.png"

# %%
# %matplotlib inline 
img = cv2.imread(path)
print(img.shape)
print(get_dimensions(img))

display(img)
display(get_sprite(img, 0, 0))
# display(get_sprite(img, 0, 1))
display(get_sprite(img, 1, 0))
# display(get_sprite(img, 1, 1))
display(get_sprite(img, 2, 0))
# display(get_sprite(img, 2, 1))

# downsample tests
x = downsample(get_sprite(img, 0,0))
display(x)
print(x.shape)
# Out:
# (156, 18, 3)
# (9, 1)
# (8, 8, 3)

# %%
test_sprites = []

for i in range(10):
    test_sprites.append(getSprite(img, 0, i))
# print(test_sprites)
display(test_sprites[-1])

# %%
test_path = "../images/test_builds/pxlsp796i8j91.png"

# %%
test_img = cv2.imread(test_path)
display(test_img)

at = 21
display(test_img[16 * (at - 1):16 * at, 16 * (at - 1):16 * at])

# %%
test_path = "../images/test_builds/test_build_1.png"

# %%
test_img = cv2.imread(test_path)
display(test_img)
test_img = test_img[34:, 30:]

display(get_sprite(test_img, 5, 5, incr = 16, offset = 0))
display(get_sprite_custom(test_img, 0, 0, 6 * 16, 32, 16))

# %%
ds = TestDataset()

# %%
print(ds[0].shape)
plt.axis("off")
plt.imshow(img)
plt.show()
# Out:
# torch.Size([16, 16, 3])

# %%
print(ds.tensor_image.shape)
# Out:
# torch.Size([1428, 1474, 3])

# %%
img = "../images/test_builds/test_build_1.png"
from torchvision.io import read_image
img = read_image(img)

# %%
img.shape
# Out:
# torch.Size([3, 1462, 1504])
